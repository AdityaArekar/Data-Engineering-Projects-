# %%
from pyspark import SparkContext, SparkConf
import collections

# %%
conf = SparkConf().setMaster("local").setAppName('Friends')
sc = SparkContext(conf=conf)

# %%
def parseLine(line):
    fields = line.split(',')
    age = int(fields[2])
    numFriends = int(fields[3])
    return (age, numFriends)

# %%
lines = sc.textFile("C:/Users/aaa17/Documents/GitHub/Data-Engineering-Projects-/Udemy Projects/spark/friends_map/friends.csv")
rdd = lines.map(parseLine)

# %%
print(rdd.collect())
# Out:
# [(28, 1023), (28, 2300), (68, 21), (35, 465), (53, 12)]

# %%
totalsByAge = rdd.mapValues(lambda x:(x,1)).reduceByKey(lambda x,y: (x[0]+y[0],x[1]+y[1]))

# %%
rdd.mapValues(lambda x:(x,1))
# Out:
# PythonRDD[26] at RDD at PythonRDD.scala:53

# %%
totalsByAge.collect()
# Out:
# [(28, (3323, 2)), (68, (21, 1)), (35, (465, 1)), (53, (12, 1))]

# %%
averagesByAge = totalsByAge.mapValues(lambda x: x[0] / x[1])

# %%
results = averagesByAge.collect()
for result in results:
    print(result)
# Out:
# (28, 1661.5)
# (68, 21.0)
# (35, 465.0)
# (53, 12.0)
